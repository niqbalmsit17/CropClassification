# %%
import numpy as np

import matplotlib.pyplot as plt

import os

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import svm, metrics

from PIL import Image

# %%
images, labels, labelNumbered = [], [], []

maize_img, wheat_img, rice_img, wheat_til, soy_img = [], [], [], [], []

mMainDir = "Crops"

mCropLabels = os.listdir(mMainDir)

mIndex = 1

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
for mCrop in mCropLabels:
    if mCrop.startswith("."):
        d = 0
        mIndex = mIndex - 1
        print("NOT ", mCrop)
    else:
        for mImage in os.listdir(mMainDir + "/" + mCrop):
            if mImage.startswith("."):
                s = 0
            else:
                mImage = np.load(mMainDir + "/" + mCrop + "/" + mImage)
                images.append(mImage.flatten() )

                labels.append(mCrop)
                labelNumbered.append(mIndex)
                #break
            #break
        print(mCrop)
    mIndex = mIndex + 1
# Out:
# NOT  .DS_Store
# Soybean
# Rice
# Wheat-Tillering
# Wheat
# Maize

# %%
images[30].shape
# Out:
# (40000,)

# %%
plt.imshow(images[50].reshape(200, 200), cmap=plt.cm.binary), labels[50]
# Out:
# (<matplotlib.image.AxesImage at 0x7fb87c142e20>, 'Wheat-Tillering')
